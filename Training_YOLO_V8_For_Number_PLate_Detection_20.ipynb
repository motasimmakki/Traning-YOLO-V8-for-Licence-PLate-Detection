# %%
# !git clone https://github.com/motasimmakki/Traning-YOLO-V8-for-Licence-PLate-Detection.git
# Out:
# Cloning into 'Traning-YOLO-V8-for-Licence-PLate-Detection'...
# remote: Enumerating objects: 126, done.
# remote: Total 126 (delta 0), reused 0 (delta 0), pack-reused 126 (from 2)
# Receiving objects: 100% (126/126), 48.90 MiB | 31.77 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
cd /content/Traning-YOLO-V8-for-Licence-PLate-Detection
# Out:
# /content/Traning-YOLO-V8-for-Licence-PLate-Detection

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.0 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=06ebbfdd21d2e1fc1d16d345ebf37f15a5f5c73d48a0f2663537edff32f8962d
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# ...

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="JV9Kt10tYoTLvLEiVgbi")
# project = rf.workspace("mochoye").project("license-plate-detector-ogxxg")
# version = project.version(2)
# dataset = version.download("yolov8")

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JV9Kt10tYoTLvLEiVgbi")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-4 in yolov8:: 100%|██████████| 48488/48488 [00:07<00:00, 6184.52it/s]

# %%
# !python /content/Traning-YOLO-V8-for-Licence-PLate-Detection/ultralytics/yolo/v8/detect/train.py model=yolov8n.pt data=/content/Traning-YOLO-V8-for-Licence-PLate-Detection/License-Plate-Recognition-4/data.yaml epochs=20
# Out:
# Streaming output truncated to the last 5000 lines.
#       19/20      2.84G     0.9876     0.3973      1.145         15        640:  18% 233/1324 [01:16<05:31,  3.29it/s]/usr/local/lib/python3.11/dist-packages/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       19/20      2.84G     0.9877     0.3972      1.146         14        640:  18% 234/1324 [01:17<05:48,  3.12it/s]/usr/local/lib/python3.11/dist-packages/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# ...

# %%
# !python /content/Traning-YOLO-V8-for-Licence-PLate-Detection/ultralytics/yolo/v8/detect/predict.py model='/content/Traning-YOLO-V8-for-Licence-PLate-Detection/runs/detect/train/weights/best.pt' source='/content/Traning-YOLO-V8-for-Licence-PLate-Detection/sample-08.mp4'
# Out:
# 2025-01-21 17:55:35.119845: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-21 17:55:35.141182: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-21 17:55:35.147498: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-21 17:55:35.162274: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python /content/Traning-YOLO-V8-for-Licence-PLate-Detection/ultralytics/yolo/v8/detect/predict.py model='/content/Traning-YOLO-V8-for-Licence-PLate-Detection/runs/detect/train/weights/best.pt' source='/content/Traning-YOLO-V8-for-Licence-PLate-Detection/sample-04.mp4'
# Out:
# 2025-01-21 18:00:12.788475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-21 18:00:12.810142: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-21 18:00:12.816345: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-21 18:00:12.839323: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
